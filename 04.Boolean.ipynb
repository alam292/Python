# %% [markdown]
# # Boolean

# %% [markdown]
# #### Boolean (bool):
#
# A Boolean is a data type that represents one of two values:- True or False.

# %% [markdown]
# #### Key Points
#
# Data type: bool
#
# Used in conditions and comparisons
#
# Result of relational and logical expressions

# %%
print(10> 8)
# Out:
# True

# %%
print(20 < 8)
# Out:
# False

# %%
print(10 == 10)
# Out:
# True

# %%
type(10 == 10)
# Out:
# bool

# %% [markdown]
# ### Evalute variable & expressions

# %% [markdown]
# #### The bool() function allows you to evaluate any value , and give you "True" or "False" in return .

# %%
x = None 
print(bool(x))
# Out:
# False

# %%
x = ()
x
# Out:
# ()

# %%
print(bool(x))
# Out:
# False

# %%
x = {}
bool(x)
# Out:
# False

# %%
x = "GFG"
print(bool(x))
# Out:
# True

# %% [markdown]
# #### Integer & Float

# %%
a = 9
print(bool(a))
# Out:
# True

# %%
b = 45.4
print(type(bool(b)))
# Out:
# <class 'bool'>

# %%
bool(b)
# Out:
# True

# %% [markdown]
# #### Boolean Operator

# %% [markdown]
# #### OR

# %%
a = 5
b = 3
c = 8
if a>b or b<c:
    print("True")
# Out:
# True

# %% [markdown]
# #### AND

# %%
a = 0
b = 2 
c = 4
if a>b and b<c:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# #### NOT

# %%
a = 0
if not a:
    print("false")
# Out:
# false
